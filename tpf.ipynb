# %% [markdown]
# # Primera archivo .dta (problemas en la data)

# %%
library(haven)
library(tidyverse)
X0_F101_parroaquias <- read_dta("F:/TESIS PRODUCCION/produc_espacial/data/0. F101 parroaquias.dta")
X0_F101_parroaquias[1:5,]
# Out:
# Registered S3 methods overwritten by 'ggplot2':
#   method         from
#   [.quosures     rlang
#   c.quosures     rlang
#   print.quosures rlang
# Registered S3 method overwritten by 'rvest':
#   method            from
#   read_xml.response xml2
# -- Attaching packages --------------------------------------- tidyverse 1.2.1 --
# v ggplot2 3.1.1       v purrr   0.3.2
# v tibble  2.1.1       v dplyr   0.8.0.1
# v tidyr   0.8.3       v stringr 1.4.0
# v readr   1.3.1       v forcats 0.4.0
# -- Conflicts ------------------------------------------ tidyverse_conflicts() --
# x dplyr::filter() masks stats::filter()
# x dplyr::lag()    masks stats::lag()
#   anio_fiscal codigo_opera_parroquia inventario_materia_prima_360
# 1 2013        1070101                 7412.2255
# 2 2013        1070102                  515.1908
# 3 2013        1070103                    0.0000
# 4 2013        1070104                    0.0000
# 5 2013        1070105                11521.1060
# ...

# %% [markdown]
# # Segundo archivo .xlsx (correcto)

# %%
library(readxl)
dataSRI <- read_excel("F:/TESIS PRODUCCION/produc_espacial/data/dataSRI.xlsx", 
                      col_types = c("numeric", "numeric", "numeric", 
                                    "numeric", "numeric", "numeric", "numeric", 
                                    "numeric", "numeric", "numeric", "numeric", "numeric", 
                                    "numeric", "numeric", "numeric", "numeric", "numeric", 
                                    "numeric", "numeric", "numeric", "numeric", "numeric", 
                                    "numeric", "numeric", "numeric", "numeric", "numeric", 
                                    "numeric", "numeric", "numeric", "numeric", "numeric", 
                                    "numeric", "numeric", "numeric", "numeric", "numeric", 
                                    "numeric", "numeric", "numeric", "numeric", "numeric", 
                                    "numeric", "numeric", "numeric", "numeric", "numeric", 
                                    "numeric", "numeric", "numeric", "numeric", "numeric", 
                                    "numeric", "numeric", "numeric", "numeric", "numeric", 
                                    "numeric", "numeric", "numeric", "numeric", "numeric", 
                                    "numeric", "numeric", "numeric", "numeric", "numeric", 
                                    "numeric", "numeric", "numeric", "numeric", "numeric", 
                                    "numeric", "numeric", "numeric", "numeric", "numeric", 
                                    "numeric", "numeric", "numeric", "numeric", "numeric", 
                                    "numeric", "numeric", "numeric", "numeric", "numeric", 
                                    "numeric", "numeric", "numeric", "numeric", "numeric", 
                                    "numeric", "numeric", "numeric", "numeric", "numeric", 
                                    "numeric", "numeric", "numeric", "numeric", "numeric", 
                                    "numeric", "numeric", "numeric", "numeric", "numeric", 
                                    "numeric", "numeric", "numeric", "numeric", "numeric", 
                                    "numeric", "numeric", "numeric", "numeric", "numeric", 
                                    "numeric", "numeric", "numeric", "numeric", "numeric", 
                                    "numeric", "numeric", "numeric", "numeric", "numeric", 
                                    "numeric", "numeric", "numeric", "numeric", "numeric", 
                                    "numeric", "numeric", "numeric", "numeric", 
                                    "numeric", "numeric", "numeric", "numeric", "numeric", 
                                    "numeric", "numeric", "numeric", "numeric", 
                                    "numeric", "numeric", "numeric", "numeric", "numeric", 
                                    "numeric", "numeric", "numeric", "numeric", 
                                    "numeric", "numeric", "numeric", "numeric", 
                                    "numeric", "numeric", "numeric", 
                                    "numeric", "numeric", "numeric", 
                                    "numeric", "numeric", "numeric", "numeric", 
                                    "numeric", "numeric", "numeric"), skip = 3)

summ_data = dataSRI[c("anio_fiscal", #año
                      "total_ingresos_1930", # total ingresos 
                      "costo_ssa_qcm_2280", # costos salarios
                      "gasto_ssa_qcm_2290", # gastos salatios
                      "total_activo_1080", # kapital
                      "cto_cln_materia_prima_2020", # COMPRAS NETAS LOCALES DE MATERIA PRIMA
                      "cto_ipr_materia_prima_2030", # IMPORTACIONES DE MATERIA PRIMA
                      "codigo_opera_parroquia")] 

summ_data$proxy_materiales = summ_data$cto_cln_materia_prima_2020 + summ_data$cto_ipr_materia_prima_2030

# %% [markdown]
# # Análisis Descriptivo

# %%
summary(summ_data)
# Out:
#   anio_fiscal   total_ingresos_1930 costo_ssa_qcm_2280 gasto_ssa_qcm_2290
#  Min.   :2013   Min.   :       0    Min.   :       0   Min.   :       0
#  1st Qu.:2014   1st Qu.:  103231    1st Qu.:       0   1st Qu.:       0
#  Median :2016   Median : 1184925    Median :       0   Median :10701333
#  Mean   :2016   Mean   :20247512    Mean   :14765209   Mean   :19468326
#  3rd Qu.:2017   3rd Qu.:33773722    3rd Qu.:21062914   3rd Qu.:29432859
#  Max.   :2018   Max.   :99965797    Max.   :99868166   Max.   :99826894
#  total_activo_1080  cto_cln_materia_prima_2020 cto_ipr_materia_prima_2030
#  Min.   :       0   Min.   :       0           Min.   :       0
#  1st Qu.:  121104   1st Qu.:       0           1st Qu.:       0
#  Median : 3710502   Median :       0           Median :       0
#  Mean   :21060554   Mean   :11009605           Mean   : 2578684
#  3rd Qu.:35558518   3rd Qu.:12367158           3rd Qu.:       0
#  Max.   :99934845   Max.   :99968199           Max.   :99636329
# ...

# %% [markdown]
# ## Descripción de las variables utilizadas
#
# anio_fiscal: año fiscal
# total_ingresos_1930: Total de ingresos
# costo_ssa_qcm_2280: Costo SUELDOS, SALARIOS Y DEMÁS REMUNERACIONES QUE CONSTITUYEN MATERIA GRAVADA DEL IESS
# gasto_ssa_qcm_2290: Gasto SUELDOS, SALARIOS Y DEMÁS REMUNERACIONES QUE CONSTITUYEN MATERIA GRAVADA DEL IESS
# total_activo_1080: Total del activo
# cto_cln_materia_prima_2020: COMPRAS NETAS LOCALES DE MATERIA PRIMA
# cto_ipr_materia_prima_2030: IMPORTACIONES DE MATERIA PRIMA
# codigo_opera_parroquia: código de parroquia

# %%
new_base = summ_data %>% 
  mutate(l_total_ingresos_1930 = log(total_ingresos_1930 + 1), 
         l_costo_ssa_qcm_2280 = log(costo_ssa_qcm_2280 + 1),
         l_gasto_ssa_qcm_2290 = log(gasto_ssa_qcm_2290 + 1),
         l_total_activo_1080  = log(total_activo_1080 + 1),
         l_proxy_materiales = log(proxy_materiales + 1)) %>% 
  select(l_total_ingresos_1930, 
         l_costo_ssa_qcm_2280, 
         l_gasto_ssa_qcm_2290,
         l_total_activo_1080, 
         l_proxy_materiales,
         codigo_opera_parroquia,
         anio_fiscal) %>% 
  arrange(codigo_opera_parroquia, anio_fiscal) #para que corra el codigo

summary(new_base)
# Out:
#  l_total_ingresos_1930 l_costo_ssa_qcm_2280 l_gasto_ssa_qcm_2290
#  Min.   : 0.00         Min.   : 0.000       Min.   : 0.00
#  1st Qu.:11.54         1st Qu.: 0.000       1st Qu.: 0.00
#  Median :13.99         Median : 0.000       Median :16.19
#  Mean   :12.73         Mean   : 7.567       Mean   :10.55
#  3rd Qu.:17.34         3rd Qu.:16.863       3rd Qu.:17.20
#  Max.   :18.42         Max.   :18.419       Max.   :18.42
#  l_total_activo_1080 l_proxy_materiales codigo_opera_parroquia  anio_fiscal
#  Min.   : 0.00       Min.   : 0.000     Min.   :1070101        Min.   :2013
#  1st Qu.:11.70       1st Qu.: 0.000     1st Qu.:1130451        1st Qu.:2014
#  Median :15.13       Median : 0.000     Median :2050456        Median :2016
#  Mean   :13.18       Mean   : 5.692     Mean   :1962696        Mean   :2016
#  3rd Qu.:17.39       3rd Qu.:16.487     3rd Qu.:2170351        3rd Qu.:2017
#  Max.   :18.42       Max.   :19.039     Max.   :4200352        Max.   :2018

# %%
options(repr.plot.width = 10, repr.plot.height = 10, repr.plot.res = 1000)
library(ggplot2)
library(patchwork)
p1 = ggplot(summ_data)+
  geom_histogram(aes(x = total_ingresos_1930))+
  ggtitle("Histograma | Sin (log)")+
  ylab("Total ingresos") +
  theme_bw() 
p2 = ggplot(summ_data)+
  geom_histogram(aes(x = log(total_ingresos_1930+1)))+
  ggtitle("Histograma | Con (log)")+
  ylab("Total ingresos") +
  theme_bw()

p1+p2
# Out:
# Warning message:
# "package 'patchwork' was built under R version 3.6.3"`stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %% [markdown]
# # Modelo

# %%
ggplot(summ_data)+
  geom_point(aes(x = new_base$l_gasto_ssa_qcm_2290, y = new_base$l_total_ingresos_1930))+
  ylab("Total ingresos (log)") +
  xlab("Gasto sueldos, salarios y demás (log)")+
  theme_bw() +
  scale_x_continuous(limits = c(3, max(new_base$l_gasto_ssa_qcm_2290))) +
  scale_y_continuous(limits = c(4.5, max(new_base$l_total_ingresos_1930))) +
  labs(caption = "Nota: las observaciones con valor 0 no fueron graficadas")
# Out:
# Warning message:
# "Removed 2478 rows containing missing values (geom_point)."
# plot without title

# %%
library(prodest)
library(estprod)

# %% [markdown]
# # Estimación

# %% [markdown]
# ## Modelo 1 usando LM (Linear Model)

# %%
mod1 = lm(new_base, formula = l_total_ingresos_1930 ~ l_gasto_ssa_qcm_2290 + l_total_activo_1080  + factor(anio_fiscal) + factor(codigo_opera_parroquia) - 1)
summary(mod1)

# %%
#Call:
#lm(formula = l_total_ingresos_1930 ~ l_gasto_ssa_qcm_2290 + l_total_activo_1080 + 
#    factor(anio_fiscal) + factor(codigo_opera_parroquia) - 1, 
#    data = new_base)
#
#Residuals:
#     Min       1Q   Median       3Q      Max 
#-14.9970  -1.1332   0.0989   1.4669  15.5016 
#
#Coefficients:
#                                       Estimate Std. Error t value Pr(>|t|)    
#l_gasto_ssa_qcm_2290                    0.11142    0.01153   9.660  < 2e-16 ***
#l_total_activo_1080                     0.31417    0.01300  24.166  < 2e-16 ***

# %% [markdown]
# ## Modelo 2 PLM (Panel Data Fixed effects)

# %%
library(plm)
mod2 = plm(new_base, formula = l_total_ingresos_1930 ~ l_gasto_ssa_qcm_2290 + l_total_activo_1080,
           model = "within",
           index = c("codigo_opera_parroquia", "anio_fiscal"))
summary(mod2)
# Out:
# Warning message:
# "package 'plm' was built under R version 3.6.3"
# Attaching package: 'plm'
#
# The following objects are masked from 'package:dplyr':
#
#     between, lag, lead
# Oneway (individual) effect Within Model
#
# Call:
# plm(formula = l_total_ingresos_1930 ~ l_gasto_ssa_qcm_2290 +
#     l_total_activo_1080, data = new_base, model = "within", index = c("codigo_opera_parroquia",
#     "anio_fiscal"))
#
# Unbalanced Panel: n = 1278, T = 1-6, N = 7543
#
# Residuals:
#       Min.    1st Qu.     Median    3rd Qu.       Max.
# -15.094573  -1.136161   0.027526   1.448868  15.669373
#
# Coefficients:
#                      Estimate Std. Error t-value  Pr(>|t|)
# l_gasto_ssa_qcm_2290 0.116737   0.011482  10.167 < 2.2e-16 ***
# l_total_activo_1080  0.318611   0.012952  24.600 < 2.2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Total Sum of Squares:    94884
# Residual Sum of Squares: 84295
# R-Squared:      0.1116
# Adj. R-Squared: -0.069821
# ...

# %% [markdown]
# ## Modelo 3.1 usando librería prodest | levinsohn_petrin()

# %%
mod3 = estprod::levinsohn_petrin(new_base,
                            formula = l_total_ingresos_1930 ~ l_gasto_ssa_qcm_2290 | l_total_activo_1080 | l_proxy_materiales, 
                            id = "codigo_opera_parroquia", time = "anio_fiscal", reps = 20)
summary(mod3)
# Out:
# Call
# estprod::levinsohn_petrin(data = new_base, formula = l_total_ingresos_1930 ~
#     l_gasto_ssa_qcm_2290 | l_total_activo_1080 | l_proxy_materiales,
#     id = "codigo_opera_parroquia", time = "anio_fiscal", reps = 20)
#
# Coefficients
#                      Estimate Std. Error z value  Pr(>|z|)
# l_gasto_ssa_qcm_2290 0.193431   0.007961  24.297 < 2.2e-16 ***
# l_total_activo_1080  0.400289   0.014550  27.511 < 2.2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# #Bootstraped standard errors.

# %% [markdown]
# ## Modelo 3.2 Usando librería estprod | prodestLP()

# %%
mod4 = prodestLP(new_base$l_total_ingresos_1930,
                 fX = new_base$l_gasto_ssa_qcm_2290,
                 sX =new_base$l_total_activo_1080, 
                 pX = new_base$l_proxy_materiales,
                 #new_base$l_gto_ivt_exploracion_otr_740,
                 idvar = new_base$codigo_opera_parroquia,
                 timevar = new_base$anio_fiscal,
                 opt='optim',
                 exit = F,
                 theta0 = NULL,
                 cluster = NULL,
                 tol = 1e-100)
summary(mod4)
# Out:
# -------------------------------------------------------------
# -               Production Function Estimation              -
# -------------------------------------------------------------
#                    Method :    LP
# -------------------------------------------------------------
#                                fX1       sX1
# Estimated Parameters      :   0.19     0.404
#                              (0.013)   (0.021)
# -------------------------------------------------------------
# N                         :  7543
# -------------------------------------------------------------
# Bootstrap repetitions     :  20
# 1st Stage Parameters      :  0.19     0.98
# Optimizer                 :  optim
# -------------------------------------------------------------
# Elapsed Time              :  0.05 mins
# -------------------------------------------------------------

# %%
nivel_significancia = data.frame(mod4@Estimates$pars / mod4@Estimates$std.errors)
colnames(nivel_significancia)[1] = "val_significancia"
nivel_significancia$signif = if_else(nivel_significancia$val_significancia>=1.96, "significativo","")
nivel_significancia
# Out:
#     val_significancia signif
# fX1 15.19989          significativo
# sX1 19.26719          significativo
